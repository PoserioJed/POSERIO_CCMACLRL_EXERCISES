# %% [markdown]
# <a href="https://colab.research.google.com/github/PoserioJed/POSERIO_CCMACLRL_EXERCISES/blob/main/exercise2b.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Exercise 2 B

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.linear_model import LinearRegression
from scipy.stats import pearsonr
import statsmodels.api as sm

# %%
df = pd.read_excel('traveldata.xlsx')

# %%
df = df.dropna()

# %% [markdown]
# ## A. Correlation

# %% [markdown]
# ### Check the relationships between each independent variable and the dependent variable using scatterplots and correlations.

# %% [markdown]
# 1. Create scatter plot between miles traveled and travel time

# %%
plt.scatter(df['Miles Traveled'], df['Travel Time'])
plt.xlabel('Miles Traveled')
plt.ylabel('Travel Time')
plt.show()

# %% [markdown]
# 2. Create scatter plot between number of deliveries and travel time

# %%
plt.scatter (df['Number of Deliveries'], df['Travel Time'])
plt.xlabel('Number of Deliveries')
plt.ylabel('Travel Time')
plt.show()

# %% [markdown]
# 3. Create scatter plot between Gas Price and Travel time

# %%
plt.scatter (df['Gas Price'], df['Travel Time'])
plt.xlabel('Gas Price')
plt.ylabel('Tavel Time')
plt.show()

# %% [markdown]
# 4. Create a pairplot

# %%
sns.pairplot(df)
plt.show()

# %% [markdown]
# 5. Calculate r-squared and p-value between Miles Traveled and Travel Time

# %%
result = sm.OLS(df['Travel Time'], df['Miles Traveled']).fit()
print(result.summary())
# Out:
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:            Travel Time   R-squared (uncentered):                   0.985
# Model:                            OLS   Adj. R-squared (uncentered):              0.983
# Method:                 Least Squares   F-statistic:                              575.6
# Date:                Mon, 18 Aug 2025   Prob (F-statistic):                    1.82e-09
# Time:                        05:44:11   Log-Likelihood:                         -11.951
# No. Observations:                  10   AIC:                                      25.90
# Df Residuals:                       9   BIC:                                      26.20
# Df Model:                           1
# Covariance Type:            nonrobust
# ==================================================================================
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# Miles Traveled     0.0781      0.003     23.991      0.000       0.071       0.085
# ==============================================================================
# Omnibus:                        2.179   Durbin-Watson:                   2.654
# Prob(Omnibus):                  0.336   Jarque-Bera (JB):                1.033
# Skew:                          -0.777   Prob(JB):                        0.597
# Kurtosis:                       2.741   Cond. No.                         1.00
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# 6. Calculate r-squared and p-value between Number of Deliveries and Travel Time

# %%
result = sm.OLS(df['Travel Time'], df['Number of Deliveries']).fit()
print(result.summary())
# Out:
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:            Travel Time   R-squared (uncentered):                   0.889
# Model:                            OLS   Adj. R-squared (uncentered):              0.876
# Method:                 Least Squares   F-statistic:                              71.75
# Date:                Mon, 18 Aug 2025   Prob (F-statistic):                    1.40e-05
# Time:                        05:46:11   Log-Likelihood:                         -21.848
# No. Observations:                  10   AIC:                                      45.70
# Df Residuals:                       9   BIC:                                      46.00
# Df Model:                           1
# Covariance Type:            nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# Number of Deliveries     1.7605      0.208      8.470      0.000       1.290       2.231
# ==============================================================================
# Omnibus:                        2.011   Durbin-Watson:                   2.191
# Prob(Omnibus):                  0.366   Jarque-Bera (JB):                0.896
# Skew:                          -0.725   Prob(JB):                        0.639
# Kurtosis:                       2.784   Cond. No.                         1.00
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# 7. Calculate r-squared and p-value between Gas Price and Travel Time

# %%
result = sm.OLS(df['Travel Time'], df['Gas Price']).fit()
print(result.summary())
# Out:
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:            Travel Time   R-squared (uncentered):                   0.983
# Model:                            OLS   Adj. R-squared (uncentered):              0.981
# Method:                 Least Squares   F-statistic:                              522.9
# Date:                Mon, 18 Aug 2025   Prob (F-statistic):                    2.78e-09
# Time:                        05:47:18   Log-Likelihood:                         -12.423
# No. Observations:                  10   AIC:                                      26.85
# Df Residuals:                       9   BIC:                                      27.15
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Gas Price      1.8110      0.079     22.867      0.000       1.632       1.990
# ==============================================================================
# Omnibus:                        0.639   Durbin-Watson:                   2.518
# Prob(Omnibus):                  0.727   Jarque-Bera (JB):                0.079
# Skew:                          -0.206   Prob(JB):                        0.961
# Kurtosis:                       2.856   Cond. No.                         1.00
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# ### Check the relationships among the independent variables using scatterplots and correlations.

# %% [markdown]
# 8. Create scatter plot between Miles Traveled and Number of Deliveries.

# %%
plt.scatter(df['Miles Traveled'], df['Number of Deliveries'])
plt.xlabel('Miles Traveled')
plt.ylabel('Number of Deliveries')
plt.show()

# %% [markdown]
# 9. Create scatter plot between Miles traveled and Gas Price

# %%
plt.scatter(df['Miles Traveled'], df['Gas Price'])
plt.xlabel('Miles Taveled')
plt.ylabel('Gas Price')
plt.show()

# %% [markdown]
# 10. Create scatter plot between Number of Deliveries and Gas Price

# %%
plt.scatter(df['Number of Deliveries'], df['Gas Price'])
plt.xlabel('Number of Deliveries')
plt.ylabel('Gas Price')
plt.show()

# %% [markdown]
# 11. Calculate r-squared and p-value between Miles Traveled and Number of Deliveries

# %%
result = sm.OLS(df['Number of Deliveries'], df['Miles Traveled']).fit()
print(result.summary())
# Out:
#                                   OLS Regression Results
# =========================================================================================
# Dep. Variable:     Number of Deliveries   R-squared (uncentered):                   0.944
# Model:                              OLS   Adj. R-squared (uncentered):              0.937
# Method:                   Least Squares   F-statistic:                              150.5
# Date:                  Mon, 18 Aug 2025   Prob (F-statistic):                    6.38e-07
# Time:                          05:53:55   Log-Likelihood:                         -12.199
# No. Observations:                    10   AIC:                                      26.40
# Df Residuals:                         9   BIC:                                      26.70
# Df Model:                             1
# Covariance Type:              nonrobust
# ==================================================================================
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# Miles Traveled     0.0409      0.003     12.267      0.000       0.033       0.049
# ==============================================================================
# Omnibus:                        1.028   Durbin-Watson:                   2.516
# Prob(Omnibus):                  0.598   Jarque-Bera (JB):                0.027
# Skew:                           0.111   Prob(JB):                        0.987
# Kurtosis:                       3.119   Cond. No.                         1.00
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# 12. Calculate r-squared and p-value between Miles Traveled and Gas Price

# %%
result =sm.OLS(df['Gas Price'], df['Miles Traveled']).fit()
print(result.summary())
# Out:
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:              Gas Price   R-squared (uncentered):                   0.953
# Model:                            OLS   Adj. R-squared (uncentered):              0.948
# Method:                 Least Squares   F-statistic:                              182.5
# Date:                Mon, 18 Aug 2025   Prob (F-statistic):                    2.79e-07
# Time:                        05:55:01   Log-Likelihood:                         -11.506
# No. Observations:                  10   AIC:                                      25.01
# Df Residuals:                       9   BIC:                                      25.32
# Df Model:                           1
# Covariance Type:            nonrobust
# ==================================================================================
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# Miles Traveled     0.0421      0.003     13.510      0.000       0.035       0.049
# ==============================================================================
# Omnibus:                        0.821   Durbin-Watson:                   2.716
# Prob(Omnibus):                  0.663   Jarque-Bera (JB):                0.143
# Skew:                           0.288   Prob(JB):                        0.931
# Kurtosis:                       2.889   Cond. No.                         1.00
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# 13. Calculate r-squared and p-value between Number of Deliveries and Gas Price

# %%
result = sm.OLS(df['Gas Price'], df['Number of Deliveries']).fit()
print(result.summary())
# Out:
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:              Gas Price   R-squared (uncentered):                   0.833
# Model:                            OLS   Adj. R-squared (uncentered):              0.815
# Method:                 Least Squares   F-statistic:                              44.95
# Date:                Mon, 18 Aug 2025   Prob (F-statistic):                    8.81e-05
# Time:                        05:55:58   Log-Likelihood:                         -17.841
# No. Observations:                  10   AIC:                                      37.68
# Df Residuals:                       9   BIC:                                      37.99
# Df Model:                           1
# Covariance Type:            nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# Number of Deliveries     0.9334      0.139      6.704      0.000       0.618       1.248
# ==============================================================================
# Omnibus:                        0.159   Durbin-Watson:                   2.328
# Prob(Omnibus):                  0.924   Jarque-Bera (JB):                0.315
# Skew:                          -0.213   Prob(JB):                        0.854
# Kurtosis:                       2.241   Cond. No.                         1.00
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# ### Correlation Summary

# %% [markdown]
# 14. Create the correlation summary

# %%
correlation = df.corr()
correlation
# Out:
#                       Miles Traveled  Number of Deliveries  Gas Price  \
# Miles Traveled              1.000000              0.955898   0.355796
# Number of Deliveries        0.955898              1.000000   0.498242
# Gas Price                   0.355796              0.498242   1.000000
# Travel Time                 0.928179              0.916443   0.267212
#
#                       Travel Time
# Miles Traveled           0.928179
# Number of Deliveries     0.916443
# Gas Price                0.267212
# Travel Time              1.000000

# %% [markdown]
# 15. Create a correlation matrix

# %%
correlation_matrix = df.corr()
print(correlation_matrix)
# Out:
#                       Miles Traveled  Number of Deliveries  Gas Price  \
# Miles Traveled              1.000000              0.955898   0.355796
# Number of Deliveries        0.955898              1.000000   0.498242
# Gas Price                   0.355796              0.498242   1.000000
# Travel Time                 0.928179              0.916443   0.267212
#
#                       Travel Time
# Miles Traveled           0.928179
# Number of Deliveries     0.916443
# Gas Price                0.267212
# Travel Time              1.000000

# %% [markdown]
# ## Building Different Regression Models

# %% [markdown]
# ### Model 1: Miles Traveled and Travel Time

# %% [markdown]
# 16. Set independent and dependent variables

# %%
X = df[['Miles Traveled']]
y = df['Travel Time']

# %% [markdown]
# 17. Build and train the model

# %%
mlr = LinearRegression()
mlr.fit(X, y)
# Out:
# LinearRegression()

# %% [markdown]
# 18. Display the statistical summary

# %%
olsmod = sm.OLS(y, X)
olsres = olsmod.fit()
print(olsres.summary())
# Out:
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:            Travel Time   R-squared (uncentered):                   0.985
# Model:                            OLS   Adj. R-squared (uncentered):              0.983
# Method:                 Least Squares   F-statistic:                              575.6
# Date:                Mon, 18 Aug 2025   Prob (F-statistic):                    1.82e-09
# Time:                        06:03:24   Log-Likelihood:                         -11.951
# No. Observations:                  10   AIC:                                      25.90
# Df Residuals:                       9   BIC:                                      26.20
# Df Model:                           1
# Covariance Type:            nonrobust
# ==================================================================================
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# Miles Traveled     0.0781      0.003     23.991      0.000       0.071       0.085
# ==============================================================================
# Omnibus:                        2.179   Durbin-Watson:                   2.654
# Prob(Omnibus):                  0.336   Jarque-Bera (JB):                1.033
# Skew:                          -0.777   Prob(JB):                        0.597
# Kurtosis:                       2.741   Cond. No.                         1.00
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# 19. Display the r-squared

# %%
r2 = olsres.rsquared
print(r2)
# Out:
# 0.9846038661190001

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipython-input-1035359046.py in <cell line: 0>()
# ----> 1 olsmod.rsquared
#
# AttributeError: 'OLS' object has no attribute 'rsquared'
